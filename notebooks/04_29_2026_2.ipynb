# %%
import os

from pathlib import Path

import matplotlib.pyplot as plt
import torch
import hashlib

from torch_geometric.data import Data, Dataset as PyGDataset

from qqe.GNN.physics_aware_NN import GNN, QuantumCircuitGraphDataset
import torch.nn as nn
from torch_geometric.loader import DataLoader

# %%
model_cliff = torch.load("../models/nn_model_mse_global_v2.pt", map_location=torch.device('cpu'), weights_only=True)
model_rand = torch.load("../models/gnn_model_mse_random.pt", map_location=torch.device('cpu'), weights_only=True)

# %%
model_rand
# Out:
# {'model_state_dict': OrderedDict([('conv_layers.0.lin_key.weight',
#                tensor([[-0.0376, -0.1198, -0.0918,  ...,  0.1110, -0.1158,  0.0051],
#                        [-0.0902,  0.0522, -0.1703,  ..., -0.0609, -0.0901,  0.0234],
#                        [ 0.0804,  0.1188,  0.0799,  ..., -0.0188,  0.1194, -0.0959],
#                        ...,
#                        [-0.0916,  0.0560, -0.2411,  ...,  0.0623, -0.0900, -0.0926],
#                        [-0.1078,  0.0769, -0.1518,  ...,  0.0045,  0.0210,  0.0867],
#                        [-0.0892, -0.1100, -0.2360,  ...,  0.0450, -0.1175,  0.0560]])),
#               ('conv_layers.0.lin_key.bias',
#                tensor([ 0.0354, -0.0808, -0.0444, -0.0778,  0.0729,  0.0467, -0.0742,  0.0767,
#                         0.0452,  0.1186,  0.0367, -0.0035, -0.0672,  0.0538,  0.0152,  0.1089,
#                         0.0516,  0.0828, -0.0108,  0.0774, -0.0317, -0.0784, -0.0455,  0.0365,
# ...

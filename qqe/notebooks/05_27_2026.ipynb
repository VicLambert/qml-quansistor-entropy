# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
import sys
import ast

from pathlib import Path
project_root = Path().resolve().parent
sys.path.append(str(project_root))

from scripts import (
    generate_dataset,
    optuna_search,
    predictions,
    training,
)

from src.utils import configure_logger

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from typing import Any 
from GNN.training.utils import collect_dataset_paths
from GNN.training.runners import MODEL_REGISTRY
from GNN.training.train_config import TrainConfig
from experiments.plotting import view_correlation

from collections.abc import Callable
Loader = Callable[..., Any]

# %%
logger = logging.getLogger(__name__)
logger.propagate = False
configure_logger(logging.INFO, logging.INFO)
# Out:
# True

# %%
seed = 5274
model_type="gnn"
epochs = 30
lr = 1e-4
loss_type = "huber"   # "mse" | "huber"
batch_size = 32
training_mode = "per_family"  # "global" | "per_family"
family = "random"  # required if training_mode == "per_family"
target = "sre"
data_dir = "../outputs/data/datasets"
model_save_path = "../outputs/models/random_model_gnn.pt"
show_progress=True
show_val_progress=False
log_every_n_batches=10
heartbeat_secs=60.0
epoch_time_warning_secs=600.0
study_name = f"optuna_search_{model_type}_{training_mode}_{family}_{target}_{seed}"
storage_url = "sqlite:///optuna_studies.db"
n_trials = 10

optuna_search(
    model_type=model_type,
    training_mode=training_mode,
    family=family,
    data_dir=data_dir,
    target=target,
    study_name=study_name,
    storage_url=storage_url,
    n_trials=n_trials,
)
# Out:
# 2026-05-27 13:05:43,210 - scripts.optuna_search - INFO - Starting Optuna hyperparameter search...
# 2026-05-27 13:08:03,541 - scripts.optuna_search - INFO - Found 40800 dataset files for target=sre in data_dir=../outputs/data/datasets.
# 2026-05-27 13:09:54,898 - scripts.optuna_search - INFO - Prepared datasets with loader_kind=gnn. Starting Optuna study with name='optuna_search_gnn_per_family_random_sre_5274' and storage='sqlite:///optuna_studies.db'...
# [I 2026-05-27 13:09:54,940] Using an existing study with name 'optuna_search_gnn_per_family_random_sre_5274' instead of creating a new one.
# 2026-05-27 13:09:54,946 - scripts.optuna_search - INFO - Running Optuna optimization for 10 trials...
# 2026-05-27 13:09:55,042 - GNN.training.train - INFO - -------- EPOCH 001 --------
# 2026-05-27 13:10:55,098 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 627/918 | loss 8.812676 | elapsed 60.1s | graphs 20064
# 2026-05-27 13:11:22,237 - GNN.training.train - INFO - Training complete (87.2s) | running validation...
# 2026-05-27 13:11:30,323 - GNN.training.train - INFO - Losses | train 7.326478 | val 3.601280 | lr 1.75e-05 | time train=87.2s val=8.1s total=95.3s
# 2026-05-27 13:11:30,325 - GNN.training.train - INFO - -------- EPOCH 002 --------
# 2026-05-27 13:12:30,372 - GNN.training.train - INFO - [Heartbeat] Epoch 2 batch 647/918 | loss 3.741228 | elapsed 60.0s | graphs 20704
# 2026-05-27 13:12:55,650 - GNN.training.train - INFO - Training complete (85.3s) | running validation...
# 2026-05-27 13:13:03,552 - GNN.training.train - INFO - Losses | train 3.643947 | val 3.128009 | lr 1.75e-05 | time train=85.3s val=7.9s total=93.2s
# 2026-05-27 13:13:03,554 - GNN.training.train - INFO - -------- EPOCH 003 --------
# 2026-05-27 13:14:03,639 - GNN.training.train - INFO - [Heartbeat] Epoch 3 batch 642/918 | loss 3.190801 | elapsed 60.1s | graphs 20544
# 2026-05-27 13:14:29,312 - GNN.training.train - INFO - Training complete (85.8s) | running validation...
# 2026-05-27 13:14:37,242 - GNN.training.train - INFO - Losses | train 3.162792 | val 2.968764 | lr 1.75e-05 | time train=85.8s val=7.9s total=93.7s
# 2026-05-27 13:14:37,245 - GNN.training.train - INFO - -------- EPOCH 004 --------
# 2026-05-27 13:15:37,329 - GNN.training.train - INFO - [Heartbeat] Epoch 4 batch 648/918 | loss 2.866937 | elapsed 60.1s | graphs 20736
# 2026-05-27 13:16:03,730 - GNN.training.train - INFO - Training complete (86.5s) | running validation...
# 2026-05-27 13:16:13,247 - GNN.training.train - INFO - Losses | train 2.853955 | val 2.545130 | lr 1.75e-05 | time train=86.5s val=9.5s total=96.0s
# 2026-05-27 13:16:13,250 - GNN.training.train - INFO - -------- EPOCH 005 --------
# 2026-05-27 13:17:13,308 - GNN.training.train - INFO - [Heartbeat] Epoch 5 batch 384/918 | loss 2.597328 | elapsed 60.1s | graphs 12288
# 2026-05-27 13:18:14,219 - GNN.training.train - INFO - [Heartbeat] Epoch 5 batch 709/918 | loss 2.560018 | elapsed 121.0s | graphs 22688
# 2026-05-27 13:18:52,424 - GNN.training.train - INFO - Training complete (159.2s) | running validation...
# 2026-05-27 13:19:09,594 - GNN.training.train - INFO - Losses | train 2.514118 | val 2.094339 | lr 1.75e-05 | time train=159.2s val=17.2s total=176.3s
# 2026-05-27 13:19:09,596 - GNN.training.train - INFO - -------- EPOCH 006 --------
# 2026-05-27 13:20:10,748 - GNN.training.train - INFO - [Heartbeat] Epoch 6 batch 328/918 | loss 2.246412 | elapsed 61.2s | graphs 10496
# 2026-05-27 13:21:11,090 - GNN.training.train - INFO - [Heartbeat] Epoch 6 batch 672/918 | loss 2.192139 | elapsed 121.5s | graphs 21504
# 2026-05-27 13:21:57,616 - GNN.training.train - INFO - Training complete (168.0s) | running validation...
# 2026-05-27 13:22:13,183 - GNN.training.train - INFO - Losses | train 2.152510 | val 2.233178 | lr 1.75e-05 | time train=168.0s val=15.6s total=183.6s
# 2026-05-27 13:22:13,184 - GNN.training.train - INFO - -------- EPOCH 007 --------
# 2026-05-27 13:23:13,724 - GNN.training.train - INFO - [Heartbeat] Epoch 7 batch 334/918 | loss 2.008912 | elapsed 60.5s | graphs 10688
# 2026-05-27 13:24:13,770 - GNN.training.train - INFO - [Heartbeat] Epoch 7 batch 657/918 | loss 1.971412 | elapsed 120.6s | graphs 21024
# 2026-05-27 13:25:01,950 - GNN.training.train - INFO - Training complete (168.8s) | running validation...
# 2026-05-27 13:25:18,877 - GNN.training.train - INFO - Losses | train 1.932594 | val 2.191288 | lr 1.75e-05 | time train=168.8s val=16.9s total=185.7s
# 2026-05-27 13:25:18,878 - GNN.training.train - INFO - -------- EPOCH 008 --------
# 2026-05-27 13:26:19,118 - GNN.training.train - INFO - [Heartbeat] Epoch 8 batch 403/918 | loss 1.836175 | elapsed 60.2s | graphs 12896
# 2026-05-27 13:27:19,218 - GNN.training.train - INFO - [Heartbeat] Epoch 8 batch 740/918 | loss 1.817722 | elapsed 120.3s | graphs 23680
# 2026-05-27 13:27:42,937 - GNN.training.train - INFO - Training complete (144.1s) | running validation...
# 2026-05-27 13:27:56,825 - GNN.training.train - INFO - Losses | train 1.810580 | val 2.198690 | lr 1.75e-05 | time train=144.1s val=13.9s total=157.9s
# 2026-05-27 13:27:56,825 - GNN.training.train - INFO - -------- EPOCH 009 --------
# 2026-05-27 13:28:57,430 - GNN.training.train - INFO - [Heartbeat] Epoch 9 batch 338/918 | loss 1.705708 | elapsed 60.6s | graphs 10816
# 2026-05-27 13:29:56,211 - GNN.training.train - INFO - Training complete (119.4s) | running validation...
# 2026-05-27 13:30:04,255 - GNN.training.train - INFO - Losses | train 1.666221 | val 2.030196 | lr 1.75e-05 | time train=119.4s val=8.0s total=127.4s
# 2026-05-27 13:30:04,257 - GNN.training.train - INFO - -------- EPOCH 010 --------
# 2026-05-27 13:31:04,266 - GNN.training.train - INFO - [Heartbeat] Epoch 10 batch 604/918 | loss 1.542687 | elapsed 60.0s | graphs 19328
# 2026-05-27 13:31:37,063 - GNN.training.train - INFO - Training complete (92.8s) | running validation...
# 2026-05-27 13:31:46,074 - GNN.training.train - INFO - Losses | train 1.536234 | val 1.848193 | lr 1.75e-05 | time train=92.8s val=9.0s total=101.8s
# 2026-05-27 13:31:46,077 - GNN.training.train - INFO - -------- EPOCH 011 --------
# 2026-05-27 13:32:46,083 - GNN.training.train - INFO - [Heartbeat] Epoch 11 batch 580/918 | loss 1.496308 | elapsed 60.0s | graphs 18560
# 2026-05-27 13:33:21,013 - GNN.training.train - INFO - Training complete (94.9s) | running validation...
# 2026-05-27 13:33:29,743 - GNN.training.train - INFO - Losses | train 1.471041 | val 1.631469 | lr 1.75e-05 | time train=94.9s val=8.7s total=103.7s
# 2026-05-27 13:33:29,745 - GNN.training.train - INFO - -------- EPOCH 012 --------
# 2026-05-27 13:34:29,753 - GNN.training.train - INFO - [Heartbeat] Epoch 12 batch 580/918 | loss 1.383857 | elapsed 60.0s | graphs 18560
# 2026-05-27 13:35:04,661 - GNN.training.train - INFO - Training complete (94.9s) | running validation...
# 2026-05-27 13:35:13,409 - GNN.training.train - INFO - Losses | train 1.356172 | val 1.620466 | lr 1.75e-05 | time train=94.9s val=8.7s total=103.7s
# 2026-05-27 13:35:13,412 - GNN.training.train - INFO - -------- EPOCH 013 --------
# 2026-05-27 13:36:13,481 - GNN.training.train - INFO - [Heartbeat] Epoch 13 batch 606/918 | loss 1.264357 | elapsed 60.1s | graphs 19392
# 2026-05-27 13:36:42,744 - GNN.training.train - INFO - Training complete (89.3s) | running validation...
# 2026-05-27 13:36:51,084 - GNN.training.train - INFO - Losses | train 1.246247 | val 1.485460 | lr 1.75e-05 | time train=89.3s val=8.3s total=97.7s
# 2026-05-27 13:36:51,086 - GNN.training.train - INFO - -------- EPOCH 014 --------
# 2026-05-27 13:37:51,187 - GNN.training.train - INFO - [Heartbeat] Epoch 14 batch 612/918 | loss 1.154908 | elapsed 60.1s | graphs 19584
# 2026-05-27 13:38:22,181 - GNN.training.train - INFO - Training complete (91.1s) | running validation...
# 2026-05-27 13:38:30,639 - GNN.training.train - INFO - Losses | train 1.153064 | val 1.230687 | lr 1.75e-05 | time train=91.1s val=8.5s total=99.6s
# 2026-05-27 13:38:30,640 - GNN.training.train - INFO - -------- EPOCH 015 --------
# 2026-05-27 13:39:30,672 - GNN.training.train - INFO - [Heartbeat] Epoch 15 batch 598/918 | loss 1.086964 | elapsed 60.0s | graphs 19136
# 2026-05-27 13:40:01,112 - GNN.training.train - INFO - Training complete (90.5s) | running validation...
# 2026-05-27 13:40:09,198 - GNN.training.train - INFO - Losses | train 1.080956 | val 1.079350 | lr 1.75e-05 | time train=90.5s val=8.1s total=98.6s
# 2026-05-27 13:40:09,201 - GNN.training.train - INFO - -------- EPOCH 016 --------
# 2026-05-27 13:41:09,304 - GNN.training.train - INFO - [Heartbeat] Epoch 16 batch 607/918 | loss 1.034063 | elapsed 60.1s | graphs 19424
# 2026-05-27 13:41:39,795 - GNN.training.train - INFO - Training complete (90.6s) | running validation...
# 2026-05-27 13:41:48,107 - GNN.training.train - INFO - Losses | train 1.028352 | val 0.996368 | lr 1.75e-05 | time train=90.6s val=8.3s total=98.9s
# 2026-05-27 13:41:48,109 - GNN.training.train - INFO - -------- EPOCH 017 --------
# 2026-05-27 13:42:48,203 - GNN.training.train - INFO - [Heartbeat] Epoch 17 batch 627/918 | loss 0.991250 | elapsed 60.1s | graphs 20064
# 2026-05-27 13:43:17,128 - GNN.training.train - INFO - Training complete (89.0s) | running validation...
# 2026-05-27 13:43:25,303 - GNN.training.train - INFO - Losses | train 0.985173 | val 0.790696 | lr 1.75e-05 | time train=89.0s val=8.2s total=97.2s
# 2026-05-27 13:43:25,306 - GNN.training.train - INFO - -------- EPOCH 018 --------
# 2026-05-27 13:44:25,359 - GNN.training.train - INFO - [Heartbeat] Epoch 18 batch 623/918 | loss 0.966323 | elapsed 60.1s | graphs 19936
# 2026-05-27 13:44:55,176 - GNN.training.train - INFO - Training complete (89.9s) | running validation...
# 2026-05-27 13:45:04,091 - GNN.training.train - INFO - Losses | train 0.947484 | val 0.692119 | lr 1.75e-05 | time train=89.9s val=8.9s total=98.8s
# 2026-05-27 13:45:04,093 - GNN.training.train - INFO - -------- EPOCH 019 --------
# 2026-05-27 13:46:04,131 - GNN.training.train - INFO - [Heartbeat] Epoch 19 batch 615/918 | loss 0.938112 | elapsed 60.0s | graphs 19680
# 2026-05-27 13:46:34,922 - GNN.training.train - INFO - Training complete (90.8s) | running validation...
# 2026-05-27 13:46:43,373 - GNN.training.train - INFO - Losses | train 0.932078 | val 0.644610 | lr 1.75e-05 | time train=90.8s val=8.5s total=99.3s
# 2026-05-27 13:46:43,376 - GNN.training.train - INFO - -------- EPOCH 020 --------
# 2026-05-27 13:47:43,464 - GNN.training.train - INFO - [Heartbeat] Epoch 20 batch 594/918 | loss 0.913346 | elapsed 60.1s | graphs 19008
# 2026-05-27 13:48:16,940 - GNN.training.train - INFO - Training complete (93.6s) | running validation...
# 2026-05-27 13:48:25,384 - GNN.training.train - INFO - Losses | train 0.906338 | val 0.587145 | lr 1.75e-05 | time train=93.6s val=8.4s total=102.0s
# 2026-05-27 13:48:25,385 - GNN.training.train - INFO - -------- EPOCH 021 --------
# 2026-05-27 13:49:25,408 - GNN.training.train - INFO - [Heartbeat] Epoch 21 batch 587/918 | loss 0.900535 | elapsed 60.0s | graphs 18784
# 2026-05-27 13:49:55,577 - GNN.training.train - INFO - Training complete (90.2s) | running validation...
# 2026-05-27 13:50:03,320 - GNN.training.train - INFO - Losses | train 0.897372 | val 0.577113 | lr 1.75e-05 | time train=90.2s val=7.7s total=97.9s
# 2026-05-27 13:50:03,323 - GNN.training.train - INFO - -------- EPOCH 022 --------
# 2026-05-27 13:51:03,407 - GNN.training.train - INFO - [Heartbeat] Epoch 22 batch 652/918 | loss 0.883774 | elapsed 60.1s | graphs 20864
# 2026-05-27 13:51:28,279 - GNN.training.train - INFO - Training complete (85.0s) | running validation...
# 2026-05-27 13:51:35,574 - GNN.training.train - INFO - Losses | train 0.886460 | val 0.533336 | lr 1.75e-05 | time train=85.0s val=7.3s total=92.3s
# 2026-05-27 13:51:35,575 - GNN.training.train - INFO - -------- EPOCH 023 --------
# 2026-05-27 13:52:35,595 - GNN.training.train - INFO - [Heartbeat] Epoch 23 batch 634/918 | loss 0.859706 | elapsed 60.0s | graphs 20288
# 2026-05-27 13:53:04,361 - GNN.training.train - INFO - Training complete (88.8s) | running validation...
# 2026-05-27 13:53:12,620 - GNN.training.train - INFO - Losses | train 0.855232 | val 0.514522 | lr 1.75e-05 | time train=88.8s val=8.3s total=97.0s
# 2026-05-27 13:53:12,622 - GNN.training.train - INFO - -------- EPOCH 024 --------
# 2026-05-27 13:54:12,648 - GNN.training.train - INFO - [Heartbeat] Epoch 24 batch 602/918 | loss 0.864344 | elapsed 60.0s | graphs 19264
# 2026-05-27 13:54:42,779 - GNN.training.train - INFO - Training complete (90.2s) | running validation...
# 2026-05-27 13:54:51,527 - GNN.training.train - INFO - Losses | train 0.860967 | val 0.498675 | lr 1.75e-05 | time train=90.2s val=8.7s total=98.9s
# 2026-05-27 13:54:51,529 - GNN.training.train - INFO - -------- EPOCH 025 --------
# 2026-05-27 13:55:51,543 - GNN.training.train - INFO - [Heartbeat] Epoch 25 batch 585/918 | loss 0.831560 | elapsed 60.0s | graphs 18720
# 2026-05-27 13:56:24,474 - GNN.training.train - INFO - Training complete (92.9s) | running validation...
# 2026-05-27 13:56:33,213 - GNN.training.train - INFO - Losses | train 0.818619 | val 0.376756 | lr 1.75e-05 | time train=92.9s val=8.7s total=101.7s
# [I 2026-05-27 13:56:33,231] Trial 3 finished with value: 0.37675560441087275 and parameters: {'batch_size': 32, 'weight_decay': 0.001199764015684655, 'grad_clip': 0.18509162163061185, 'gnn_hidden': 64, 'gnn_heads': 2, 'global_hidden': 64, 'reg_hidden': 128, 'num_layers': 3, 'dropout_rate': 0.4432064463448076, 'lr': 1.7524544424288475e-05, 'loss_type': 'mse'}. Best is trial 1 with value: 0.057792215977850205.
# 2026-05-27 13:56:33,568 - GNN.training.train - INFO - -------- EPOCH 001 --------
# 2026-05-27 13:57:33,597 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 311/459 | loss 8.163170 | elapsed 60.0s | graphs 19904
# 2026-05-27 13:57:58,780 - GNN.training.train - INFO - Training complete (85.2s) | running validation...
# 2026-05-27 13:58:06,549 - GNN.training.train - INFO - Losses | train 7.223324 | val 3.645150 | lr 2.08e-04 | time train=85.2s val=7.8s total=93.0s
# 2026-05-27 13:58:06,551 - GNN.training.train - INFO - -------- EPOCH 002 --------
# 2026-05-27 13:59:06,712 - GNN.training.train - INFO - [Heartbeat] Epoch 2 batch 335/459 | loss 4.042342 | elapsed 60.2s | graphs 21440
# 2026-05-27 13:59:27,715 - GNN.training.train - INFO - Training complete (81.2s) | running validation...
# 2026-05-27 13:59:35,575 - GNN.training.train - INFO - Losses | train 3.843495 | val 5.347135 | lr 2.08e-04 | time train=81.2s val=7.9s total=89.0s
# 2026-05-27 13:59:35,575 - GNN.training.train - INFO - -------- EPOCH 003 --------
# 2026-05-27 14:00:35,688 - GNN.training.train - INFO - [Heartbeat] Epoch 3 batch 340/459 | loss 2.715972 | elapsed 60.1s | graphs 21760
# 2026-05-27 14:00:56,704 - GNN.training.train - INFO - Training complete (81.1s) | running validation...
# 2026-05-27 14:01:05,015 - GNN.training.train - INFO - Losses | train 2.610348 | val 7.850304 | lr 2.08e-04 | time train=81.1s val=8.3s total=89.4s
# 2026-05-27 14:01:05,017 - GNN.training.train - INFO - -------- EPOCH 004 --------
# 2026-05-27 14:02:05,034 - GNN.training.train - INFO - [Heartbeat] Epoch 4 batch 349/459 | loss 1.748500 | elapsed 60.0s | graphs 22336
# 2026-05-27 14:02:23,969 - GNN.training.train - INFO - Training complete (79.0s) | running validation...
# 2026-05-27 14:02:31,669 - GNN.training.train - INFO - Losses | train 1.665691 | val 8.904316 | lr 2.08e-04 | time train=79.0s val=7.7s total=86.7s
# 2026-05-27 14:02:31,670 - GNN.training.train - INFO - -------- EPOCH 005 --------
# 2026-05-27 14:03:31,810 - GNN.training.train - INFO - [Heartbeat] Epoch 5 batch 322/459 | loss 1.198393 | elapsed 60.1s | graphs 20608
# 2026-05-27 14:03:57,563 - GNN.training.train - INFO - Training complete (85.9s) | running validation...
# 2026-05-27 14:04:06,253 - GNN.training.train - INFO - Losses | train 1.144082 | val 8.765236 | lr 2.08e-04 | time train=85.9s val=8.7s total=94.6s
# 2026-05-27 14:04:06,253 - GNN.training.train - INFO - -------- EPOCH 006 --------
# 2026-05-27 14:05:06,288 - GNN.training.train - INFO - [Heartbeat] Epoch 6 batch 333/459 | loss 0.909159 | elapsed 60.0s | graphs 21312
# 2026-05-27 14:05:32,330 - GNN.training.train - INFO - Training complete (86.1s) | running validation...
# 2026-05-27 14:05:43,335 - GNN.training.train - INFO - Losses | train 0.892377 | val 8.410050 | lr 2.08e-04 | time train=86.1s val=11.0s total=97.1s
# 2026-05-27 14:05:43,336 - GNN.training.train - INFO - -------- EPOCH 007 --------
# 2026-05-27 14:06:43,372 - GNN.training.train - INFO - [Heartbeat] Epoch 7 batch 243/459 | loss 0.816459 | elapsed 60.0s | graphs 15552
# 2026-05-27 14:07:25,018 - GNN.training.train - INFO - Training complete (101.7s) | running validation...
# 2026-05-27 14:07:32,881 - GNN.training.train - INFO - Losses | train 0.783629 | val 8.232520 | lr 1.04e-04 | time train=101.7s val=7.9s total=109.5s
# 2026-05-27 14:07:32,882 - GNN.training.train - INFO - -------- EPOCH 008 --------
# 2026-05-27 14:08:32,967 - GNN.training.train - INFO - [Heartbeat] Epoch 8 batch 324/459 | loss 0.660092 | elapsed 60.1s | graphs 20736
# 2026-05-27 14:08:58,175 - GNN.training.train - INFO - Training complete (85.3s) | running validation...
# 2026-05-27 14:09:05,970 - GNN.training.train - INFO - Losses | train 0.650481 | val 8.176515 | lr 1.04e-04 | time train=85.3s val=7.8s total=93.1s
# 2026-05-27 14:09:05,971 - GNN.training.train - INFO - -------- EPOCH 009 --------
# 2026-05-27 14:10:06,069 - GNN.training.train - INFO - [Heartbeat] Epoch 9 batch 309/459 | loss 0.673413 | elapsed 60.1s | graphs 19776
# 2026-05-27 14:10:35,528 - GNN.training.train - INFO - Training complete (89.6s) | running validation...
# 2026-05-27 14:10:43,946 - GNN.training.train - INFO - Losses | train 0.656384 | val 8.223396 | lr 1.04e-04 | time train=89.6s val=8.4s total=98.0s
# 2026-05-27 14:10:43,946 - GNN.training.train - INFO - -------- EPOCH 010 --------
# 2026-05-27 14:11:44,159 - GNN.training.train - INFO - [Heartbeat] Epoch 10 batch 301/459 | loss 0.596994 | elapsed 60.2s | graphs 19264
# 2026-05-27 14:12:13,385 - GNN.training.train - INFO - Training complete (89.4s) | running validation...
# 2026-05-27 14:12:21,887 - GNN.training.train - INFO - Losses | train 0.579581 | val 8.035886 | lr 1.04e-04 | time train=89.4s val=8.5s total=97.9s
# 2026-05-27 14:12:21,887 - GNN.training.train - INFO - -------- EPOCH 011 --------
# 2026-05-27 14:13:21,903 - GNN.training.train - INFO - [Heartbeat] Epoch 11 batch 317/459 | loss 0.562934 | elapsed 60.0s | graphs 20288
# 2026-05-27 14:13:48,340 - GNN.training.train - INFO - Training complete (86.5s) | running validation...
# 2026-05-27 14:13:56,310 - GNN.training.train - INFO - Losses | train 0.560556 | val 8.019832 | lr 1.04e-04 | time train=86.5s val=8.0s total=94.4s
# 2026-05-27 14:13:56,312 - GNN.training.train - INFO - Early stopping at epoch 011 | best val 3.645150 | patience exhausted (10/10)
# [I 2026-05-27 14:13:56,327] Trial 4 finished with value: 3.645150011661006 and parameters: {'batch_size': 64, 'weight_decay': 0.00048450068873232623, 'grad_clip': 0.9682796313885678, 'gnn_hidden': 16, 'gnn_heads': 8, 'global_hidden': 128, 'reg_hidden': 16, 'num_layers': 3, 'dropout_rate': 0.49708051767810785, 'lr': 0.000207524799483888, 'loss_type': 'mse'}. Best is trial 1 with value: 0.057792215977850205.
# 2026-05-27 14:13:56,679 - GNN.training.train - INFO - -------- EPOCH 001 --------
# 2026-05-27 14:14:59,783 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 2/230 | loss 2.825741 | elapsed 63.1s | graphs 256
# 2026-05-27 14:16:04,081 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 4/230 | loss 2.842109 | elapsed 127.4s | graphs 512
# 2026-05-27 14:17:39,469 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 6/230 | loss 2.901708 | elapsed 222.8s | graphs 768
# 2026-05-27 14:19:17,554 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 8/230 | loss 2.903915 | elapsed 320.9s | graphs 1024
# 2026-05-27 14:21:06,037 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 10/230 | loss 2.917561 | elapsed 429.4s | graphs 1280
# 2026-05-27 14:22:43,672 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 12/230 | loss 2.914307 | elapsed 527.0s | graphs 1536
# 2026-05-27 14:24:10,154 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 14/230 | loss 2.905278 | elapsed 613.5s | graphs 1792
# 2026-05-27 14:25:40,995 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 16/230 | loss 2.895513 | elapsed 704.3s | graphs 2048
# 2026-05-27 14:26:50,165 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 18/230 | loss 2.897089 | elapsed 773.5s | graphs 2304
# 2026-05-27 14:27:55,900 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 20/230 | loss 2.886104 | elapsed 839.2s | graphs 2560
# 2026-05-27 14:29:04,389 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 22/230 | loss 2.892146 | elapsed 907.7s | graphs 2816
# 2026-05-27 14:30:04,988 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 24/230 | loss 2.880726 | elapsed 968.3s | graphs 3072
# 2026-05-27 14:31:12,287 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 26/230 | loss 2.882183 | elapsed 1035.6s | graphs 3328
# 2026-05-27 14:32:15,710 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 28/230 | loss 2.870278 | elapsed 1099.0s | graphs 3584
# 2026-05-27 14:33:29,370 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 30/230 | loss 2.867343 | elapsed 1172.7s | graphs 3840

# %%
seed = np.random.randint(0, 10000)
model_type="nn"
epochs = 30
lr = 1e-4
loss_type = "huber"   # "mse" | "huber"
batch_size = 32
training_mode = "per_family"  # "global" | "per_family"
family = "random"  # required if training_mode == "per_family"
target = "sre"
data_dir = "../outputs/data/datasets"
model_save_path = "../outputs/models/random_model_nn.pt"
show_progress=True
show_val_progress=False
log_every_n_batches=10
heartbeat_secs=60.0
epoch_time_warning_secs=600.0
study_name = f"optuna_search_{model_type}_{training_mode}_{family}_{target}_{seed}"
storage_url = "sqlite:///optuna_studies.db"
n_trials = 10

optuna_search(
    model_type=model_type,
    training_mode=training_mode,
    family=family,
    data_dir=data_dir,
    target=target,
    study_name=study_name,
    storage_url=storage_url,
    n_trials=n_trials,
)

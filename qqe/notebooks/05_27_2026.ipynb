# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
import sys
import ast

from pathlib import Path
project_root = Path().resolve().parent
sys.path.append(str(project_root))

from scripts import (
    generate_dataset,
    optuna_search,
    predictions,
    training,
)

from src.utils import configure_logger

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from typing import Any 
from GNN.training.utils import collect_dataset_paths
from GNN.training.runners import MODEL_REGISTRY
from GNN.training.train_config import TrainConfig
from experiments.plotting import view_correlation

from collections.abc import Callable
Loader = Callable[..., Any]

# %%
logger = logging.getLogger(__name__)
logger.propagate = False
configure_logger(logging.INFO, logging.INFO)
# Out:
# True

# %%
seed = 5274
model_type="gnn"
epochs = 30
lr = 1e-4
loss_type = "huber"   # "mse" | "huber"
batch_size = 32
training_mode = "per_family"  # "global" | "per_family"
family = "random"  # required if training_mode == "per_family"
target = "sre"
data_dir = "../outputs/data/datasets"
model_save_path = "../outputs/models/random_model_gnn.pt"
show_progress=True
show_val_progress=False
log_every_n_batches=10
heartbeat_secs=60.0
epoch_time_warning_secs=600.0
study_name = f"optuna_search_{model_type}_{training_mode}_{family}_{target}_{seed}"
storage_url = "sqlite:///optuna_studies.db"
n_trials = 10

optuna_search(
    model_type=model_type,
    training_mode=training_mode,
    family=family,
    data_dir=data_dir,
    target=target,
    study_name=study_name,
    storage_url=storage_url,
    n_trials=n_trials,
)
# Out:
# 2026-05-28 12:55:25,769 - scripts.optuna_search - INFO - Starting Optuna hyperparameter search...
# 2026-05-28 13:00:39,438 - scripts.optuna_search - INFO - Found 40800 dataset files for target=sre in data_dir=../outputs/data/datasets.
# 2026-05-28 13:02:46,601 - scripts.optuna_search - INFO - Prepared datasets with loader_kind=gnn. Starting Optuna study with name='optuna_search_gnn_per_family_random_sre_5274' and storage='sqlite:///optuna_studies.db'...
# [I 2026-05-28 13:02:47,245] Using an existing study with name 'optuna_search_gnn_per_family_random_sre_5274' instead of creating a new one.
# 2026-05-28 13:02:47,251 - scripts.optuna_search - INFO - Running Optuna optimization for 10 trials...
# 2026-05-28 13:02:47,627 - GNN.training.train - INFO - -------- EPOCH 001 --------
# 2026-05-28 13:03:47,656 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 522/1836 | loss 0.036222 | elapsed 60.0s | graphs 8352
# 2026-05-28 13:04:47,768 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 1057/1836 | loss 0.024483 | elapsed 120.1s | graphs 16912
# 2026-05-28 13:05:47,844 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 1587/1836 | loss 0.019361 | elapsed 180.2s | graphs 25392
# 2026-05-28 13:06:16,754 - GNN.training.train - INFO - Training complete (209.1s) | running validation...
# 2026-05-28 13:06:30,549 - GNN.training.train - INFO - Losses | train 0.017801 | val 0.002826 | lr 1.51e-05 | time train=209.1s val=13.8s total=222.9s
# 2026-05-28 13:06:30,559 - GNN.training.train - INFO - -------- EPOCH 002 --------
# 2026-05-28 13:07:30,646 - GNN.training.train - INFO - [Heartbeat] Epoch 2 batch 526/1836 | loss 0.007500 | elapsed 60.1s | graphs 8416
# 2026-05-28 13:08:30,682 - GNN.training.train - INFO - [Heartbeat] Epoch 2 batch 1050/1836 | loss 0.007154 | elapsed 120.1s | graphs 16800
# 2026-05-28 13:09:30,735 - GNN.training.train - INFO - [Heartbeat] Epoch 2 batch 1587/1836 | loss 0.006846 | elapsed 180.2s | graphs 25392
# 2026-05-28 13:09:59,508 - GNN.training.train - INFO - Training complete (208.9s) | running validation...
# 2026-05-28 13:10:12,833 - GNN.training.train - INFO - Losses | train 0.006755 | val 0.003161 | lr 1.51e-05 | time train=208.9s val=13.3s total=222.3s
# 2026-05-28 13:10:12,834 - GNN.training.train - INFO - -------- EPOCH 003 --------
# 2026-05-28 13:11:12,871 - GNN.training.train - INFO - [Heartbeat] Epoch 3 batch 519/1836 | loss 0.005828 | elapsed 60.0s | graphs 8304
# 2026-05-28 13:12:12,975 - GNN.training.train - INFO - [Heartbeat] Epoch 3 batch 1051/1836 | loss 0.005785 | elapsed 120.1s | graphs 16816
# 2026-05-28 13:13:12,987 - GNN.training.train - INFO - [Heartbeat] Epoch 3 batch 1581/1836 | loss 0.005730 | elapsed 180.2s | graphs 25296
# 2026-05-28 13:13:41,957 - GNN.training.train - INFO - Training complete (209.1s) | running validation...
# 2026-05-28 13:13:55,582 - GNN.training.train - INFO - Losses | train 0.005703 | val 0.003047 | lr 1.51e-05 | time train=209.1s val=13.6s total=222.7s
# 2026-05-28 13:13:55,582 - GNN.training.train - INFO - -------- EPOCH 004 --------
# 2026-05-28 13:14:55,584 - GNN.training.train - INFO - [Heartbeat] Epoch 4 batch 526/1836 | loss 0.005233 | elapsed 60.0s | graphs 8416
# 2026-05-28 13:15:55,620 - GNN.training.train - INFO - [Heartbeat] Epoch 4 batch 1070/1836 | loss 0.005237 | elapsed 120.0s | graphs 17120
# 2026-05-28 13:16:55,675 - GNN.training.train - INFO - [Heartbeat] Epoch 4 batch 1610/1836 | loss 0.005139 | elapsed 180.1s | graphs 25760
# 2026-05-28 13:17:21,302 - GNN.training.train - INFO - Training complete (205.7s) | running validation...
# 2026-05-28 13:17:34,853 - GNN.training.train - INFO - Losses | train 0.005107 | val 0.003528 | lr 1.51e-05 | time train=205.7s val=13.5s total=219.3s
# 2026-05-28 13:17:34,853 - GNN.training.train - INFO - -------- EPOCH 005 --------
# 2026-05-28 13:18:34,919 - GNN.training.train - INFO - [Heartbeat] Epoch 5 batch 510/1836 | loss 0.004815 | elapsed 60.1s | graphs 8160
# 2026-05-28 13:19:35,004 - GNN.training.train - INFO - [Heartbeat] Epoch 5 batch 1024/1836 | loss 0.004807 | elapsed 120.1s | graphs 16384
# 2026-05-28 13:20:35,012 - GNN.training.train - INFO - [Heartbeat] Epoch 5 batch 1539/1836 | loss 0.004768 | elapsed 180.2s | graphs 24624
# 2026-05-28 13:21:09,310 - GNN.training.train - INFO - Training complete (214.5s) | running validation...
# 2026-05-28 13:21:23,072 - GNN.training.train - INFO - Losses | train 0.004698 | val 0.001953 | lr 1.51e-05 | time train=214.5s val=13.8s total=228.2s
# 2026-05-28 13:21:23,084 - GNN.training.train - INFO - -------- EPOCH 006 --------
# 2026-05-28 13:22:23,187 - GNN.training.train - INFO - [Heartbeat] Epoch 6 batch 514/1836 | loss 0.004473 | elapsed 60.1s | graphs 8224
# 2026-05-28 13:23:23,229 - GNN.training.train - INFO - [Heartbeat] Epoch 6 batch 1030/1836 | loss 0.004433 | elapsed 120.1s | graphs 16480
# 2026-05-28 13:24:23,238 - GNN.training.train - INFO - [Heartbeat] Epoch 6 batch 1544/1836 | loss 0.004376 | elapsed 180.2s | graphs 24704
# 2026-05-28 13:24:57,252 - GNN.training.train - INFO - Training complete (214.2s) | running validation...
# 2026-05-28 13:25:10,859 - GNN.training.train - INFO - Losses | train 0.004355 | val 0.002388 | lr 1.51e-05 | time train=214.2s val=13.6s total=227.8s
# 2026-05-28 13:25:10,860 - GNN.training.train - INFO - -------- EPOCH 007 --------
# 2026-05-28 13:26:11,010 - GNN.training.train - INFO - [Heartbeat] Epoch 7 batch 514/1836 | loss 0.004133 | elapsed 60.1s | graphs 8224
# 2026-05-28 13:27:11,034 - GNN.training.train - INFO - [Heartbeat] Epoch 7 batch 1033/1836 | loss 0.004129 | elapsed 120.2s | graphs 16528
# 2026-05-28 13:28:11,100 - GNN.training.train - INFO - [Heartbeat] Epoch 7 batch 1553/1836 | loss 0.004109 | elapsed 180.2s | graphs 24848
# 2026-05-28 13:28:43,887 - GNN.training.train - INFO - Training complete (213.0s) | running validation...
# 2026-05-28 13:28:57,332 - GNN.training.train - INFO - Losses | train 0.004100 | val 0.002581 | lr 1.51e-05 | time train=213.0s val=13.4s total=226.5s
# 2026-05-28 13:28:57,333 - GNN.training.train - INFO - -------- EPOCH 008 --------
# 2026-05-28 13:29:57,424 - GNN.training.train - INFO - [Heartbeat] Epoch 8 batch 513/1836 | loss 0.003965 | elapsed 60.1s | graphs 8208
# 2026-05-28 13:30:57,503 - GNN.training.train - INFO - [Heartbeat] Epoch 8 batch 1026/1836 | loss 0.003929 | elapsed 120.2s | graphs 16416
# 2026-05-28 13:31:57,514 - GNN.training.train - INFO - [Heartbeat] Epoch 8 batch 1536/1836 | loss 0.003929 | elapsed 180.2s | graphs 24576
# 2026-05-28 13:32:32,874 - GNN.training.train - INFO - Training complete (215.5s) | running validation...
# 2026-05-28 13:32:46,717 - GNN.training.train - INFO - Losses | train 0.003907 | val 0.002092 | lr 1.51e-05 | time train=215.5s val=13.8s total=229.4s
# 2026-05-28 13:32:46,718 - GNN.training.train - INFO - -------- EPOCH 009 --------
# 2026-05-28 13:33:46,797 - GNN.training.train - INFO - [Heartbeat] Epoch 9 batch 514/1836 | loss 0.003873 | elapsed 60.1s | graphs 8224
# 2026-05-28 13:34:46,880 - GNN.training.train - INFO - [Heartbeat] Epoch 9 batch 1032/1836 | loss 0.003801 | elapsed 120.2s | graphs 16512
# 2026-05-28 13:35:47,001 - GNN.training.train - INFO - [Heartbeat] Epoch 9 batch 1547/1836 | loss 0.003795 | elapsed 180.3s | graphs 24752
# 2026-05-28 13:36:20,791 - GNN.training.train - INFO - Training complete (214.1s) | running validation...
# 2026-05-28 13:36:34,504 - GNN.training.train - INFO - Losses | train 0.003789 | val 0.002148 | lr 1.51e-05 | time train=214.1s val=13.7s total=227.8s
# 2026-05-28 13:36:34,505 - GNN.training.train - INFO - -------- EPOCH 010 --------
# 2026-05-28 13:37:34,573 - GNN.training.train - INFO - [Heartbeat] Epoch 10 batch 519/1836 | loss 0.003708 | elapsed 60.1s | graphs 8304
# 2026-05-28 13:38:34,628 - GNN.training.train - INFO - [Heartbeat] Epoch 10 batch 1037/1836 | loss 0.003638 | elapsed 120.1s | graphs 16592
# 2026-05-28 13:39:34,642 - GNN.training.train - INFO - [Heartbeat] Epoch 10 batch 1551/1836 | loss 0.003641 | elapsed 180.1s | graphs 24816
# 2026-05-28 13:40:09,243 - GNN.training.train - INFO - Training complete (214.7s) | running validation...
# 2026-05-28 13:40:23,080 - GNN.training.train - INFO - Losses | train 0.003618 | val 0.001731 | lr 1.51e-05 | time train=214.7s val=13.8s total=228.6s
# 2026-05-28 13:40:23,091 - GNN.training.train - INFO - -------- EPOCH 011 --------
# 2026-05-28 13:41:23,215 - GNN.training.train - INFO - [Heartbeat] Epoch 11 batch 522/1836 | loss 0.003629 | elapsed 60.1s | graphs 8352
# 2026-05-28 13:42:23,324 - GNN.training.train - INFO - [Heartbeat] Epoch 11 batch 1031/1836 | loss 0.003608 | elapsed 120.2s | graphs 16496
# 2026-05-28 13:43:23,353 - GNN.training.train - INFO - [Heartbeat] Epoch 11 batch 1541/1836 | loss 0.003562 | elapsed 180.3s | graphs 24656
# 2026-05-28 13:43:58,232 - GNN.training.train - INFO - Training complete (215.1s) | running validation...
# 2026-05-28 13:44:12,153 - GNN.training.train - INFO - Losses | train 0.003540 | val 0.001811 | lr 1.51e-05 | time train=215.1s val=13.9s total=229.1s
# 2026-05-28 13:44:12,154 - GNN.training.train - INFO - -------- EPOCH 012 --------
# 2026-05-28 13:45:12,157 - GNN.training.train - INFO - [Heartbeat] Epoch 12 batch 512/1836 | loss 0.003493 | elapsed 60.0s | graphs 8192
# 2026-05-28 13:46:12,161 - GNN.training.train - INFO - [Heartbeat] Epoch 12 batch 1036/1836 | loss 0.003483 | elapsed 120.0s | graphs 16576
# 2026-05-28 13:47:12,230 - GNN.training.train - INFO - [Heartbeat] Epoch 12 batch 1550/1836 | loss 0.003482 | elapsed 180.1s | graphs 24800
# 2026-05-28 13:47:46,184 - GNN.training.train - INFO - Training complete (214.0s) | running validation...
# 2026-05-28 13:48:00,397 - GNN.training.train - INFO - Losses | train 0.003452 | val 0.001894 | lr 1.51e-05 | time train=214.0s val=14.2s total=228.2s
# 2026-05-28 13:48:00,398 - GNN.training.train - INFO - -------- EPOCH 013 --------
# 2026-05-28 13:49:00,477 - GNN.training.train - INFO - [Heartbeat] Epoch 13 batch 512/1836 | loss 0.003318 | elapsed 60.1s | graphs 8192
# 2026-05-28 13:50:00,524 - GNN.training.train - INFO - [Heartbeat] Epoch 13 batch 1023/1836 | loss 0.003352 | elapsed 120.1s | graphs 16368
# 2026-05-28 13:51:00,544 - GNN.training.train - INFO - [Heartbeat] Epoch 13 batch 1548/1836 | loss 0.003340 | elapsed 180.1s | graphs 24768
# 2026-05-28 13:51:33,308 - GNN.training.train - INFO - Training complete (212.9s) | running validation...
# 2026-05-28 13:51:46,574 - GNN.training.train - INFO - Losses | train 0.003349 | val 0.001733 | lr 1.51e-05 | time train=212.9s val=13.3s total=226.2s
# 2026-05-28 13:51:46,575 - GNN.training.train - INFO - -------- EPOCH 014 --------
# 2026-05-28 13:52:46,610 - GNN.training.train - INFO - [Heartbeat] Epoch 14 batch 531/1836 | loss 0.003286 | elapsed 60.0s | graphs 8496
# 2026-05-28 13:53:46,637 - GNN.training.train - INFO - [Heartbeat] Epoch 14 batch 1061/1836 | loss 0.003249 | elapsed 120.1s | graphs 16976
# 2026-05-28 13:54:46,641 - GNN.training.train - INFO - [Heartbeat] Epoch 14 batch 1587/1836 | loss 0.003253 | elapsed 180.1s | graphs 25392
# 2026-05-28 13:55:14,947 - GNN.training.train - INFO - Training complete (208.4s) | running validation...
# 2026-05-28 13:55:28,193 - GNN.training.train - INFO - Losses | train 0.003237 | val 0.001760 | lr 1.51e-05 | time train=208.4s val=13.2s total=221.6s
# 2026-05-28 13:55:28,194 - GNN.training.train - INFO - -------- EPOCH 015 --------
# 2026-05-28 13:56:28,298 - GNN.training.train - INFO - [Heartbeat] Epoch 15 batch 536/1836 | loss 0.003140 | elapsed 60.1s | graphs 8576
# 2026-05-28 13:57:28,300 - GNN.training.train - INFO - [Heartbeat] Epoch 15 batch 1056/1836 | loss 0.003194 | elapsed 120.1s | graphs 16896
# 2026-05-28 13:58:28,341 - GNN.training.train - INFO - [Heartbeat] Epoch 15 batch 1557/1836 | loss 0.003223 | elapsed 180.1s | graphs 24912
# 2026-05-28 13:59:00,829 - GNN.training.train - INFO - Training complete (212.6s) | running validation...
# 2026-05-28 13:59:15,285 - GNN.training.train - INFO - Losses | train 0.003208 | val 0.001677 | lr 1.51e-05 | time train=212.6s val=14.5s total=227.1s
# 2026-05-28 13:59:15,298 - GNN.training.train - INFO - -------- EPOCH 016 --------
# 2026-05-28 14:00:15,372 - GNN.training.train - INFO - [Heartbeat] Epoch 16 batch 525/1836 | loss 0.003205 | elapsed 60.1s | graphs 8400
# 2026-05-28 14:01:15,406 - GNN.training.train - INFO - [Heartbeat] Epoch 16 batch 1053/1836 | loss 0.003198 | elapsed 120.1s | graphs 16848
# 2026-05-28 14:02:15,508 - GNN.training.train - INFO - [Heartbeat] Epoch 16 batch 1574/1836 | loss 0.003160 | elapsed 180.2s | graphs 25184
# 2026-05-28 14:02:44,888 - GNN.training.train - INFO - Training complete (209.6s) | running validation...
# 2026-05-28 14:02:57,979 - GNN.training.train - INFO - Losses | train 0.003151 | val 0.001745 | lr 1.51e-05 | time train=209.6s val=13.1s total=222.7s
# 2026-05-28 14:02:57,979 - GNN.training.train - INFO - -------- EPOCH 017 --------
# 2026-05-28 14:03:58,086 - GNN.training.train - INFO - [Heartbeat] Epoch 17 batch 539/1836 | loss 0.003138 | elapsed 60.1s | graphs 8624
# 2026-05-28 14:04:58,107 - GNN.training.train - INFO - [Heartbeat] Epoch 17 batch 1068/1836 | loss 0.003094 | elapsed 120.1s | graphs 17088
# 2026-05-28 14:05:58,145 - GNN.training.train - INFO - [Heartbeat] Epoch 17 batch 1601/1836 | loss 0.003105 | elapsed 180.2s | graphs 25616
# 2026-05-28 14:06:24,042 - GNN.training.train - INFO - Training complete (206.1s) | running validation...
# 2026-05-28 14:06:36,970 - GNN.training.train - INFO - Losses | train 0.003109 | val 0.001658 | lr 1.51e-05 | time train=206.1s val=12.9s total=219.0s
# 2026-05-28 14:06:36,981 - GNN.training.train - INFO - -------- EPOCH 018 --------
# 2026-05-28 14:07:37,051 - GNN.training.train - INFO - [Heartbeat] Epoch 18 batch 544/1836 | loss 0.003026 | elapsed 60.1s | graphs 8704
# 2026-05-28 14:08:37,120 - GNN.training.train - INFO - [Heartbeat] Epoch 18 batch 1081/1836 | loss 0.003034 | elapsed 120.1s | graphs 17296
# 2026-05-28 14:09:37,211 - GNN.training.train - INFO - [Heartbeat] Epoch 18 batch 1623/1836 | loss 0.003061 | elapsed 180.2s | graphs 25968
# 2026-05-28 14:10:00,962 - GNN.training.train - INFO - Training complete (204.0s) | running validation...
# 2026-05-28 14:10:13,868 - GNN.training.train - INFO - Losses | train 0.003069 | val 0.001808 | lr 1.51e-05 | time train=204.0s val=12.9s total=216.9s
# 2026-05-28 14:10:13,868 - GNN.training.train - INFO - -------- EPOCH 019 --------
# 2026-05-28 14:11:13,922 - GNN.training.train - INFO - [Heartbeat] Epoch 19 batch 536/1836 | loss 0.003026 | elapsed 60.1s | graphs 8576
# 2026-05-28 14:12:13,971 - GNN.training.train - INFO - [Heartbeat] Epoch 19 batch 1062/1836 | loss 0.003010 | elapsed 120.1s | graphs 16992
# 2026-05-28 14:13:14,066 - GNN.training.train - INFO - [Heartbeat] Epoch 19 batch 1611/1836 | loss 0.003006 | elapsed 180.2s | graphs 25776
# 2026-05-28 14:13:38,530 - GNN.training.train - INFO - Training complete (204.7s) | running validation...
# 2026-05-28 14:13:51,377 - GNN.training.train - INFO - Losses | train 0.003016 | val 0.001639 | lr 1.51e-05 | time train=204.7s val=12.8s total=217.5s
# 2026-05-28 14:13:51,390 - GNN.training.train - INFO - -------- EPOCH 020 --------
# 2026-05-28 14:14:51,475 - GNN.training.train - INFO - [Heartbeat] Epoch 20 batch 533/1836 | loss 0.003075 | elapsed 60.1s | graphs 8528
# 2026-05-28 14:15:51,488 - GNN.training.train - INFO - [Heartbeat] Epoch 20 batch 1055/1836 | loss 0.003078 | elapsed 120.1s | graphs 16880
# 2026-05-28 14:16:51,577 - GNN.training.train - INFO - [Heartbeat] Epoch 20 batch 1583/1836 | loss 0.003053 | elapsed 180.2s | graphs 25328
# 2026-05-28 14:17:20,392 - GNN.training.train - INFO - Training complete (209.0s) | running validation...
# 2026-05-28 14:17:33,790 - GNN.training.train - INFO - Losses | train 0.003022 | val 0.001655 | lr 1.51e-05 | time train=209.0s val=13.4s total=222.4s
# 2026-05-28 14:17:33,791 - GNN.training.train - INFO - -------- EPOCH 021 --------
# 2026-05-28 14:18:33,854 - GNN.training.train - INFO - [Heartbeat] Epoch 21 batch 529/1836 | loss 0.002951 | elapsed 60.1s | graphs 8464
# 2026-05-28 14:19:33,888 - GNN.training.train - INFO - [Heartbeat] Epoch 21 batch 1051/1836 | loss 0.002978 | elapsed 120.1s | graphs 16816
# 2026-05-28 14:20:33,901 - GNN.training.train - INFO - [Heartbeat] Epoch 21 batch 1567/1836 | loss 0.002974 | elapsed 180.1s | graphs 25072
# 2026-05-28 14:21:04,910 - GNN.training.train - INFO - Training complete (211.1s) | running validation...
# 2026-05-28 14:21:18,446 - GNN.training.train - INFO - Losses | train 0.002971 | val 0.001767 | lr 1.51e-05 | time train=211.1s val=13.5s total=224.7s
# 2026-05-28 14:21:18,447 - GNN.training.train - INFO - -------- EPOCH 022 --------
# 2026-05-28 14:22:18,571 - GNN.training.train - INFO - [Heartbeat] Epoch 22 batch 513/1836 | loss 0.002892 | elapsed 60.1s | graphs 8208
# 2026-05-28 14:23:18,598 - GNN.training.train - INFO - [Heartbeat] Epoch 22 batch 1048/1836 | loss 0.002930 | elapsed 120.2s | graphs 16768
# 2026-05-28 14:24:18,665 - GNN.training.train - INFO - [Heartbeat] Epoch 22 batch 1591/1836 | loss 0.002929 | elapsed 180.2s | graphs 25456
# 2026-05-28 14:24:45,630 - GNN.training.train - INFO - Training complete (207.2s) | running validation...
# 2026-05-28 14:24:58,797 - GNN.training.train - INFO - Losses | train 0.002933 | val 0.001838 | lr 1.51e-05 | time train=207.2s val=13.2s total=220.4s
# 2026-05-28 14:24:58,799 - GNN.training.train - INFO - -------- EPOCH 023 --------
# 2026-05-28 14:25:58,881 - GNN.training.train - INFO - [Heartbeat] Epoch 23 batch 522/1836 | loss 0.002941 | elapsed 60.1s | graphs 8352
# 2026-05-28 14:26:58,957 - GNN.training.train - INFO - [Heartbeat] Epoch 23 batch 1055/1836 | loss 0.002915 | elapsed 120.2s | graphs 16880
# 2026-05-28 14:27:58,964 - GNN.training.train - INFO - [Heartbeat] Epoch 23 batch 1584/1836 | loss 0.002925 | elapsed 180.2s | graphs 25344
# 2026-05-28 14:28:28,159 - GNN.training.train - INFO - Training complete (209.4s) | running validation...
# 2026-05-28 14:28:42,017 - GNN.training.train - INFO - Losses | train 0.002920 | val 0.001706 | lr 1.51e-05 | time train=209.4s val=13.9s total=223.2s
# 2026-05-28 14:28:42,018 - GNN.training.train - INFO - -------- EPOCH 024 --------
# 2026-05-28 14:29:42,098 - GNN.training.train - INFO - [Heartbeat] Epoch 24 batch 541/1836 | loss 0.002921 | elapsed 60.1s | graphs 8656
# 2026-05-28 14:30:42,209 - GNN.training.train - INFO - [Heartbeat] Epoch 24 batch 1082/1836 | loss 0.002919 | elapsed 120.2s | graphs 17312
# 2026-05-28 14:31:42,329 - GNN.training.train - INFO - [Heartbeat] Epoch 24 batch 1610/1836 | loss 0.002947 | elapsed 180.3s | graphs 25760
# 2026-05-28 14:32:08,303 - GNN.training.train - INFO - Training complete (206.3s) | running validation...
# 2026-05-28 14:32:21,199 - GNN.training.train - INFO - Losses | train 0.002936 | val 0.001759 | lr 1.51e-05 | time train=206.3s val=12.9s total=219.2s
# 2026-05-28 14:32:21,199 - GNN.training.train - INFO - -------- EPOCH 025 --------
# 2026-05-28 14:33:21,249 - GNN.training.train - INFO - [Heartbeat] Epoch 25 batch 542/1836 | loss 0.002984 | elapsed 60.0s | graphs 8672
# 2026-05-28 14:34:21,301 - GNN.training.train - INFO - [Heartbeat] Epoch 25 batch 1073/1836 | loss 0.002927 | elapsed 120.1s | graphs 17168
# 2026-05-28 14:35:21,387 - GNN.training.train - INFO - [Heartbeat] Epoch 25 batch 1605/1836 | loss 0.002913 | elapsed 180.2s | graphs 25680
# 2026-05-28 14:35:47,455 - GNN.training.train - INFO - Training complete (206.3s) | running validation...
# 2026-05-28 14:36:01,704 - GNN.training.train - INFO - Losses | train 0.002912 | val 0.001718 | lr 7.57e-06 | time train=206.3s val=14.2s total=220.5s
# [I 2026-05-28 14:36:01,769] Trial 6 finished with value: 0.0016389531029192001 and parameters: {'batch_size': 16, 'weight_decay': 0.0011100615729802686, 'grad_clip': 18.68332578469687, 'gnn_hidden': 128, 'gnn_heads': 8, 'global_hidden': 128, 'reg_hidden': 64, 'num_layers': 3, 'dropout_rate': 0.14466592901950354, 'lr': 1.5131621801102364e-05, 'loss_type': 'huber'}. Best is trial 6 with value: 0.0016389531029192001.
# 2026-05-28 14:36:02,657 - GNN.training.train - INFO - -------- EPOCH 001 --------
# 2026-05-28 14:37:02,841 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 292/459 | loss 0.121291 | elapsed 60.2s | graphs 18688
# 2026-05-28 14:37:37,452 - GNN.training.train - INFO - Training complete (94.8s) | running validation...
# 2026-05-28 14:37:47,558 - GNN.training.train - INFO - Losses | train 0.107858 | val 0.063626 | lr 1.07e-04 | time train=94.8s val=10.1s total=104.9s
# 2026-05-28 14:37:47,561 - GNN.training.train - INFO - -------- EPOCH 002 --------
# 2026-05-28 14:38:47,771 - GNN.training.train - INFO - [Heartbeat] Epoch 2 batch 297/459 | loss 0.069765 | elapsed 60.2s | graphs 19008
# 2026-05-28 14:39:21,693 - GNN.training.train - INFO - Training complete (94.1s) | running validation...
# 2026-05-28 14:39:32,110 - GNN.training.train - INFO - Losses | train 0.064349 | val 0.031891 | lr 1.07e-04 | time train=94.1s val=10.4s total=104.5s
# 2026-05-28 14:39:32,114 - GNN.training.train - INFO - -------- EPOCH 003 --------
# 2026-05-28 14:40:32,155 - GNN.training.train - INFO - [Heartbeat] Epoch 3 batch 295/459 | loss 0.045468 | elapsed 60.0s | graphs 18880
# 2026-05-28 14:41:06,876 - GNN.training.train - INFO - Training complete (94.8s) | running validation...
# 2026-05-28 14:41:17,462 - GNN.training.train - INFO - Losses | train 0.042698 | val 0.016560 | lr 1.07e-04 | time train=94.8s val=10.6s total=105.3s
# 2026-05-28 14:41:17,464 - GNN.training.train - INFO - -------- EPOCH 004 --------
# 2026-05-28 14:42:17,673 - GNN.training.train - INFO - [Heartbeat] Epoch 4 batch 294/459 | loss 0.033254 | elapsed 60.2s | graphs 18816
# 2026-05-28 14:42:52,123 - GNN.training.train - INFO - Training complete (94.7s) | running validation...
# 2026-05-28 14:43:02,406 - GNN.training.train - INFO - Losses | train 0.032174 | val 0.013100 | lr 1.07e-04 | time train=94.7s val=10.3s total=104.9s
# 2026-05-28 14:43:02,407 - GNN.training.train - INFO - -------- EPOCH 005 --------
# 2026-05-28 14:44:02,431 - GNN.training.train - INFO - [Heartbeat] Epoch 5 batch 293/459 | loss 0.026882 | elapsed 60.0s | graphs 18752
# 2026-05-28 14:44:36,655 - GNN.training.train - INFO - Training complete (94.2s) | running validation...
# 2026-05-28 14:44:47,130 - GNN.training.train - INFO - Losses | train 0.025805 | val 0.009287 | lr 1.07e-04 | time train=94.2s val=10.5s total=104.7s
# 2026-05-28 14:44:47,132 - GNN.training.train - INFO - -------- EPOCH 006 --------
# 2026-05-28 14:45:47,197 - GNN.training.train - INFO - [Heartbeat] Epoch 6 batch 295/459 | loss 0.022061 | elapsed 60.1s | graphs 18880
# 2026-05-28 14:46:21,540 - GNN.training.train - INFO - Training complete (94.4s) | running validation...
# 2026-05-28 14:46:31,598 - GNN.training.train - INFO - Losses | train 0.021606 | val 0.008066 | lr 1.07e-04 | time train=94.4s val=10.1s total=104.5s
# 2026-05-28 14:46:31,599 - GNN.training.train - INFO - -------- EPOCH 007 --------
# 2026-05-28 14:47:31,821 - GNN.training.train - INFO - [Heartbeat] Epoch 7 batch 286/459 | loss 0.018648 | elapsed 60.2s | graphs 18304
# 2026-05-28 14:48:08,626 - GNN.training.train - INFO - Training complete (97.0s) | running validation...
# 2026-05-28 14:48:18,927 - GNN.training.train - INFO - Losses | train 0.018181 | val 0.007472 | lr 1.07e-04 | time train=97.0s val=10.3s total=107.3s
# 2026-05-28 14:48:18,929 - GNN.training.train - INFO - -------- EPOCH 008 --------
# 2026-05-28 14:49:19,043 - GNN.training.train - INFO - [Heartbeat] Epoch 8 batch 291/459 | loss 0.015954 | elapsed 60.1s | graphs 18624
# 2026-05-28 14:49:54,237 - GNN.training.train - INFO - Training complete (95.3s) | running validation...
# 2026-05-28 14:50:04,578 - GNN.training.train - INFO - Losses | train 0.015470 | val 0.007999 | lr 1.07e-04 | time train=95.3s val=10.3s total=105.6s
# 2026-05-28 14:50:04,578 - GNN.training.train - INFO - -------- EPOCH 009 --------
# 2026-05-28 14:51:04,643 - GNN.training.train - INFO - [Heartbeat] Epoch 9 batch 290/459 | loss 0.013817 | elapsed 60.1s | graphs 18560
# 2026-05-28 14:51:40,441 - GNN.training.train - INFO - Training complete (95.9s) | running validation...
# 2026-05-28 14:51:50,752 - GNN.training.train - INFO - Losses | train 0.013485 | val 0.009213 | lr 1.07e-04 | time train=95.9s val=10.3s total=106.2s
# 2026-05-28 14:51:50,753 - GNN.training.train - INFO - -------- EPOCH 010 --------
# 2026-05-28 14:52:50,916 - GNN.training.train - INFO - [Heartbeat] Epoch 10 batch 300/459 | loss 0.012392 | elapsed 60.2s | graphs 19200
# 2026-05-28 14:53:22,985 - GNN.training.train - INFO - Training complete (92.2s) | running validation...
# 2026-05-28 14:53:32,835 - GNN.training.train - INFO - Losses | train 0.011969 | val 0.014216 | lr 1.07e-04 | time train=92.2s val=9.8s total=102.1s
# 2026-05-28 14:53:32,836 - GNN.training.train - INFO - -------- EPOCH 011 --------
# 2026-05-28 14:54:32,938 - GNN.training.train - INFO - [Heartbeat] Epoch 11 batch 314/459 | loss 0.010733 | elapsed 60.1s | graphs 20096
# 2026-05-28 14:55:01,556 - GNN.training.train - INFO - Training complete (88.7s) | running validation...
# 2026-05-28 14:55:11,843 - GNN.training.train - INFO - Losses | train 0.010511 | val 0.011930 | lr 1.07e-04 | time train=88.7s val=10.3s total=99.0s
# 2026-05-28 14:55:11,843 - GNN.training.train - INFO - -------- EPOCH 012 --------
# 2026-05-28 14:56:12,026 - GNN.training.train - INFO - [Heartbeat] Epoch 12 batch 296/459 | loss 0.009760 | elapsed 60.2s | graphs 18944
# 2026-05-28 14:56:45,857 - GNN.training.train - INFO - Training complete (94.0s) | running validation...
# 2026-05-28 14:56:55,993 - GNN.training.train - INFO - Losses | train 0.009617 | val 0.013861 | lr 1.07e-04 | time train=94.0s val=10.1s total=104.2s
# 2026-05-28 14:56:55,994 - GNN.training.train - INFO - -------- EPOCH 013 --------
# 2026-05-28 14:57:56,119 - GNN.training.train - INFO - [Heartbeat] Epoch 13 batch 302/459 | loss 0.008795 | elapsed 60.1s | graphs 19328
# 2026-05-28 14:58:29,076 - GNN.training.train - INFO - Training complete (93.1s) | running validation...
# 2026-05-28 14:58:39,288 - GNN.training.train - INFO - Losses | train 0.008719 | val 0.014053 | lr 5.36e-05 | time train=93.1s val=10.2s total=103.3s
# 2026-05-28 14:58:39,289 - GNN.training.train - INFO - -------- EPOCH 014 --------
# 2026-05-28 14:59:39,481 - GNN.training.train - INFO - [Heartbeat] Epoch 14 batch 288/459 | loss 0.008322 | elapsed 60.2s | graphs 18432
# 2026-05-28 15:00:14,787 - GNN.training.train - INFO - Training complete (95.5s) | running validation...
# 2026-05-28 15:00:24,796 - GNN.training.train - INFO - Losses | train 0.008224 | val 0.017480 | lr 5.36e-05 | time train=95.5s val=10.0s total=105.5s
# 2026-05-28 15:00:24,797 - GNN.training.train - INFO - -------- EPOCH 015 --------
# 2026-05-28 15:01:24,994 - GNN.training.train - INFO - [Heartbeat] Epoch 15 batch 290/459 | loss 0.007841 | elapsed 60.2s | graphs 18560
# 2026-05-28 15:02:00,218 - GNN.training.train - INFO - Training complete (95.4s) | running validation...
# 2026-05-28 15:02:10,365 - GNN.training.train - INFO - Losses | train 0.007925 | val 0.017991 | lr 5.36e-05 | time train=95.4s val=10.1s total=105.6s
# 2026-05-28 15:02:10,366 - GNN.training.train - INFO - -------- EPOCH 016 --------
# 2026-05-28 15:03:10,551 - GNN.training.train - INFO - [Heartbeat] Epoch 16 batch 293/459 | loss 0.007750 | elapsed 60.2s | graphs 18752
# 2026-05-28 15:03:45,095 - GNN.training.train - INFO - Training complete (94.7s) | running validation...
# 2026-05-28 15:03:55,283 - GNN.training.train - INFO - Losses | train 0.007678 | val 0.018594 | lr 5.36e-05 | time train=94.7s val=10.2s total=104.9s
# 2026-05-28 15:03:55,285 - GNN.training.train - INFO - -------- EPOCH 017 --------
# 2026-05-28 15:04:55,383 - GNN.training.train - INFO - [Heartbeat] Epoch 17 batch 299/459 | loss 0.007401 | elapsed 60.1s | graphs 19136
# 2026-05-28 15:05:29,329 - GNN.training.train - INFO - Training complete (94.0s) | running validation...
# 2026-05-28 15:05:39,211 - GNN.training.train - INFO - Losses | train 0.007380 | val 0.021986 | lr 5.36e-05 | time train=94.0s val=9.9s total=103.9s
# 2026-05-28 15:05:39,213 - GNN.training.train - INFO - Early stopping at epoch 017 | best val 0.007472 | patience exhausted (10/10)
# [I 2026-05-28 15:05:39,230] Trial 7 finished with value: 0.0074720636521484335 and parameters: {'batch_size': 64, 'weight_decay': 3.0739304755730944e-05, 'grad_clip': 4.044269740415743, 'gnn_hidden': 16, 'gnn_heads': 8, 'global_hidden': 64, 'reg_hidden': 32, 'num_layers': 2, 'dropout_rate': 0.4531965268473256, 'lr': 0.00010723114519416072, 'loss_type': 'mse'}. Best is trial 6 with value: 0.0016389531029192001.
# 2026-05-28 15:05:39,733 - GNN.training.train - INFO - -------- EPOCH 001 --------
# 2026-05-28 15:06:39,822 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 532/918 | loss 0.019179 | elapsed 60.1s | graphs 17024
# 2026-05-28 15:07:20,519 - GNN.training.train - INFO - Training complete (100.8s) | running validation...
# 2026-05-28 15:07:29,330 - GNN.training.train - INFO - Losses | train 0.013797 | val 0.003083 | lr 3.78e-04 | time train=100.8s val=8.8s total=109.6s
# 2026-05-28 15:07:29,333 - GNN.training.train - INFO - -------- EPOCH 002 --------
# 2026-05-28 15:08:29,389 - GNN.training.train - INFO - [Heartbeat] Epoch 2 batch 598/918 | loss 0.005121 | elapsed 60.1s | graphs 19136
# 2026-05-28 15:09:01,404 - GNN.training.train - INFO - Training complete (92.1s) | running validation...
# 2026-05-28 15:09:10,540 - GNN.training.train - INFO - Losses | train 0.004959 | val 0.002566 | lr 3.78e-04 | time train=92.1s val=9.1s total=101.2s
# 2026-05-28 15:09:10,543 - GNN.training.train - INFO - -------- EPOCH 003 --------
# 2026-05-28 15:10:10,574 - GNN.training.train - INFO - [Heartbeat] Epoch 3 batch 596/918 | loss 0.004407 | elapsed 60.0s | graphs 19072
# 2026-05-28 15:10:42,769 - GNN.training.train - INFO - Training complete (92.2s) | running validation...
# 2026-05-28 15:10:51,856 - GNN.training.train - INFO - Losses | train 0.004327 | val 0.002625 | lr 3.78e-04 | time train=92.2s val=9.1s total=101.3s
# 2026-05-28 15:10:51,858 - GNN.training.train - INFO - -------- EPOCH 004 --------
# 2026-05-28 15:11:51,906 - GNN.training.train - INFO - [Heartbeat] Epoch 4 batch 589/918 | loss 0.004124 | elapsed 60.0s | graphs 18848
# 2026-05-28 15:12:25,846 - GNN.training.train - INFO - Training complete (94.0s) | running validation...
# 2026-05-28 15:12:34,873 - GNN.training.train - INFO - Losses | train 0.004147 | val 0.003018 | lr 3.78e-04 | time train=94.0s val=9.0s total=103.0s
# 2026-05-28 15:12:34,874 - GNN.training.train - INFO - -------- EPOCH 005 --------
# 2026-05-28 15:13:34,944 - GNN.training.train - INFO - [Heartbeat] Epoch 5 batch 591/918 | loss 0.004062 | elapsed 60.1s | graphs 18912
# 2026-05-28 15:14:08,707 - GNN.training.train - INFO - Training complete (93.8s) | running validation...
# 2026-05-28 15:14:17,576 - GNN.training.train - INFO - Losses | train 0.004020 | val 0.002784 | lr 3.78e-04 | time train=93.8s val=8.9s total=102.7s
# 2026-05-28 15:14:17,578 - GNN.training.train - INFO - -------- EPOCH 006 --------
# 2026-05-28 15:15:17,597 - GNN.training.train - INFO - [Heartbeat] Epoch 6 batch 589/918 | loss 0.003957 | elapsed 60.0s | graphs 18848
# 2026-05-28 15:15:51,384 - GNN.training.train - INFO - Training complete (93.8s) | running validation...
# 2026-05-28 15:16:00,292 - GNN.training.train - INFO - Losses | train 0.003940 | val 0.003955 | lr 3.78e-04 | time train=93.8s val=8.9s total=102.7s
# 2026-05-28 15:16:00,293 - GNN.training.train - INFO - -------- EPOCH 007 --------
# 2026-05-28 15:17:00,341 - GNN.training.train - INFO - [Heartbeat] Epoch 7 batch 574/918 | loss 0.003926 | elapsed 60.0s | graphs 18368
# 2026-05-28 15:17:37,418 - GNN.training.train - INFO - Training complete (97.1s) | running validation...
# 2026-05-28 15:17:46,377 - GNN.training.train - INFO - Losses | train 0.003901 | val 0.004467 | lr 3.78e-04 | time train=97.1s val=9.0s total=106.1s
# 2026-05-28 15:17:46,377 - GNN.training.train - INFO - -------- EPOCH 008 --------
# 2026-05-28 15:18:46,469 - GNN.training.train - INFO - [Heartbeat] Epoch 8 batch 578/918 | loss 0.003973 | elapsed 60.1s | graphs 18496
# 2026-05-28 15:19:21,380 - GNN.training.train - INFO - Training complete (95.0s) | running validation...
# 2026-05-28 15:19:30,332 - GNN.training.train - INFO - Losses | train 0.003936 | val 0.004571 | lr 1.89e-04 | time train=95.0s val=9.0s total=104.0s
# 2026-05-28 15:19:30,332 - GNN.training.train - INFO - -------- EPOCH 009 --------
# 2026-05-28 15:20:30,385 - GNN.training.train - INFO - [Heartbeat] Epoch 9 batch 585/918 | loss 0.003720 | elapsed 60.1s | graphs 18720
# 2026-05-28 15:21:04,452 - GNN.training.train - INFO - Training complete (94.1s) | running validation...
# 2026-05-28 15:21:13,484 - GNN.training.train - INFO - Losses | train 0.003736 | val 0.003383 | lr 1.89e-04 | time train=94.1s val=9.0s total=103.2s
# 2026-05-28 15:21:13,484 - GNN.training.train - INFO - -------- EPOCH 010 --------
# 2026-05-28 15:22:13,571 - GNN.training.train - INFO - [Heartbeat] Epoch 10 batch 585/918 | loss 0.003679 | elapsed 60.1s | graphs 18720
# 2026-05-28 15:22:47,613 - GNN.training.train - INFO - Training complete (94.1s) | running validation...
# 2026-05-28 15:22:56,587 - GNN.training.train - INFO - Losses | train 0.003696 | val 0.003860 | lr 1.89e-04 | time train=94.1s val=9.0s total=103.1s
# 2026-05-28 15:22:56,589 - GNN.training.train - INFO - -------- EPOCH 011 --------
# 2026-05-28 15:23:56,683 - GNN.training.train - INFO - [Heartbeat] Epoch 11 batch 586/918 | loss 0.003655 | elapsed 60.1s | graphs 18752
# 2026-05-28 15:24:30,837 - GNN.training.train - INFO - Training complete (94.2s) | running validation...
# 2026-05-28 15:24:39,834 - GNN.training.train - INFO - Losses | train 0.003670 | val 0.003054 | lr 1.89e-04 | time train=94.2s val=9.0s total=103.2s
# 2026-05-28 15:24:39,834 - GNN.training.train - INFO - -------- EPOCH 012 --------
# 2026-05-28 15:25:39,920 - GNN.training.train - INFO - [Heartbeat] Epoch 12 batch 589/918 | loss 0.003621 | elapsed 60.1s | graphs 18848
# 2026-05-28 15:26:13,450 - GNN.training.train - INFO - Training complete (93.6s) | running validation...
# 2026-05-28 15:26:22,521 - GNN.training.train - INFO - Losses | train 0.003639 | val 0.003750 | lr 1.89e-04 | time train=93.6s val=9.1s total=102.7s
# 2026-05-28 15:26:22,522 - GNN.training.train - INFO - Early stopping at epoch 012 | best val 0.002566 | patience exhausted (10/10)
# [I 2026-05-28 15:26:22,537] Trial 8 finished with value: 0.0025662956462588673 and parameters: {'batch_size': 32, 'weight_decay': 0.0015991914918986818, 'grad_clip': 0.04607839772148517, 'gnn_hidden': 16, 'gnn_heads': 2, 'global_hidden': 64, 'reg_hidden': 32, 'num_layers': 4, 'dropout_rate': 0.2803127151909102, 'lr': 0.00037787465414380075, 'loss_type': 'huber'}. Best is trial 6 with value: 0.0016389531029192001.
# 2026-05-28 15:26:23,089 - GNN.training.train - INFO - -------- EPOCH 001 --------
# 2026-05-28 15:27:53,933 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 7/459 | loss 0.152585 | elapsed 90.8s | graphs 448
# 2026-05-28 15:29:31,502 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 11/459 | loss 0.142789 | elapsed 188.4s | graphs 704
# 2026-05-28 15:30:57,246 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 15/459 | loss 0.136508 | elapsed 274.2s | graphs 960
# 2026-05-28 15:31:57,493 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 17/459 | loss 0.130522 | elapsed 334.4s | graphs 1088
# 2026-05-28 15:33:21,313 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 32/459 | loss 0.089470 | elapsed 418.2s | graphs 2048
# 2026-05-28 15:34:23,995 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 44/459 | loss 0.072955 | elapsed 480.9s | graphs 2816
# 2026-05-28 15:35:42,796 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 51/459 | loss 0.066424 | elapsed 559.7s | graphs 3264
# 2026-05-28 15:36:42,990 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 57/459 | loss 0.062313 | elapsed 619.9s | graphs 3648
# 2026-05-28 15:38:13,184 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 66/459 | loss 0.057292 | elapsed 710.1s | graphs 4224
# 2026-05-28 15:39:20,150 - GNN.training.train - INFO - [Heartbeat] Epoch 1 batch 74/459 | loss 0.053920 | elapsed 777.1s | graphs 4736
# [W 2026-05-28 15:40:48,602] Trial 9 failed with parameters: {'batch_size': 64, 'weight_decay': 6.871561653571451e-05, 'grad_clip': 14.063588783307573, 'gnn_hidden': 128, 'gnn_heads': 8, 'global_hidden': 16, 'reg_hidden': 16, 'num_layers': 4, 'dropout_rate': 0.00806572551806406, 'lr': 0.00011742565993924138, 'loss_type': 'huber'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\optuna\study\_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "C:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\scripts\optuna_search.py", line 68, in objective_fn
#     return MODEL_REGISTRY[model_type]["objective_fn"](
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\src\GNN\parameter_search\helpers.py", line 52, in objective_GNN
#     model, hist, dev = train_model(
#                        ^^^^^^^^^^^^
#   File "C:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\src\GNN\training\train.py", line 232, in train_model
#     train_loss, train_time = _run_train_epoch(
#                              ^^^^^^^^^^^^^^^^^
#   File "C:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\src\GNN\training\train.py", line 131, in _run_train_epoch
#     scaler.step(optimizer)
#   File "c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\amp\grad_scaler.py", line 478, in step
#     retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\amp\grad_scaler.py", line 371, in _maybe_opt_step
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\amp\grad_scaler.py", line 371, in <genexpr>
#     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#                ^^^^^^^^
# KeyboardInterrupt
# [W 2026-05-28 15:40:48,623] Trial 9 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 21
#      17 study_name = f"optuna_search_{model_type}_{training_mode}_{family}_{target}_{seed}"
#      18 storage_url = "sqlite:///optuna_studies.db"
#      19 n_trials = 10
#      20
# ---> 21 optuna_search(
#      22     model_type=model_type,
#      23     training_mode=training_mode,
#      24     family=family,
#
# File ~\Desktop\Université\Research\qml-quansistor-entropy\qqe\scripts\optuna_search.py:74, in main(model_type, training_mode, family, data_dir, target, epochs, n_trials, study_name, storage_url)
#      68     return MODEL_REGISTRY[model_type]["objective_fn"](
#      69         trial,
#      70         prepared_data=prepared_data,
#      71         epochs=epochs,
#      72     )
#      73 logger.info(f"Running Optuna optimization for {n_trials} trials...")
# ---> 74 study.optimize(objective_fn, n_trials=n_trials, gc_after_trial=True)
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)    397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)    488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\optuna\study\_optimize.py:68, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      66 try:
#      67     if n_jobs == 1:
# ---> 68         _optimize_sequential(
#      69             study,
#      70             func,
#      71             n_trials,
#      72             timeout,
#      73             catch,
#      74             callbacks,
#      75             gc_after_trial,
#      76             reseed_sampler_rng=False,
#      77             time_start=None,
#      78             progress_bar=progress_bar,
#      79         )
#      80     else:
#      81         if n_jobs == -1:
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\optuna\study\_optimize.py:165, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     162         break
#     164 try:
# --> 165     frozen_trial_id = _run_trial(study, func, catch)
#     166 finally:
#     167     # The following line mitigates memory problems that can be occurred in some
#     168     # environments (e.g., services that use computing containers such as GitHub Actions).
#     169     # Please refer to the following PR for further details:
#     170     # https://github.com/optuna/optuna/pull/325.
#     171     if gc_after_trial:
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\optuna\study\_optimize.py:263, in _run_trial(study, func, catch)
#     256         assert False, "Should not reach."
#     258 if (
#     259     updated_state == TrialState.FAIL
#     260     and func_err is not None
#     261     and not isinstance(func_err, catch)
#     262 ):
# --> 263     raise func_err
#     264 return trial._trial_id
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\optuna\study\_optimize.py:206, in _run_trial(study, func, catch)
#     204 with get_heartbeat_thread(trial._trial_id, study._storage):
#     205     try:
# --> 206         value_or_values = func(trial)
#     207     except exceptions.TrialPruned as e:
#     208         # TODO(mamu): Handle multi-objective cases.
#     209         state = TrialState.PRUNED
#
# File ~\Desktop\Université\Research\qml-quansistor-entropy\qqe\scripts\optuna_search.py:68, in main.<locals>.objective_fn(trial)
#      67 def objective_fn(trial):
# ---> 68     return MODEL_REGISTRY[model_type]["objective_fn"](
#      69         trial,
#      70         prepared_data=prepared_data,
#      71         epochs=epochs,
#      72     )
#
# File ~\Desktop\Université\Research\qml-quansistor-entropy\qqe\src\GNN\parameter_search\helpers.py:52, in objective_GNN(trial, prepared_data, epochs)
#      33 model_hparams = {
#      34     "gnn_hidden": trial.suggest_categorical("gnn_hidden", [16, 32, 64, 128]),
#      35     "gnn_heads": trial.suggest_categorical("gnn_heads", [2, 4, 8]),
#    (...)     39     "dropout_rate": trial.suggest_float("dropout_rate", 0.0, 0.5),
#      40 }
#      41 model = GNN(
#      42     node_in_dim=prepared_data.node_in_dim,
#      43     global_in_dim=prepared_data.global_in_dim,
#    (...)     49     dropout_rate=model_hparams["dropout_rate"],
#      50 )
# ---> 52 model, hist, dev = train_model(
#      53     model,
#      54     train_loader,
#      55     val_loader,
#      56     epochs=epochs,
#      57     lr=trial.suggest_float("lr", 1e-5, 3e-3, log=True),
#      58     loss_type=trial.suggest_categorical("loss_type", ["mse", "huber"]),
#      59     scheduler="plateau",
#      60     show_progress=False,
#      61     show_val_progress=False,
#      62     weight_decay=train_hparams["weight_decay"],
#      63     grad_clip=train_hparams["grad_clip"],
#      64     early_stopping_patience=train_hparams["early_stopping_patience"],
#      65     early_stopping_min_delta=train_hparams["early_stopping_min_delta"],
#      66 )
#      68 return min(hist.val_loss)
#
# File ~\Desktop\Université\Research\qml-quansistor-entropy\qqe\src\GNN\training\train.py:232, in train_model(model, train_loader, val_loader, epochs, lr, weight_decay, device, loss_type, huber_delta, grad_clip, early_stopping_patience, early_stopping_min_delta, use_amp, scheduler, show_progress, show_val_progress, log_every_n_batches, heartbeat_secs, epoch_time_warning_secs)
#     229 epoch_start_time = time.time()
#     230 logger.info(f"-------- EPOCH {epoch:03d} --------")  # noqa: G004
# --> 232 train_loss, train_time = _run_train_epoch(
#     233     model=model,
#     234     loader=train_loader,
#     235     optimizer=optimizer,
#     236     loss_fn=loss_fn,
#     237     scaler=scaler,
#     238     device=dev,
#     239     use_amp=use_amp,
#     240     grad_clip=grad_clip,
#     241     epoch_idx=epoch,
#     242     num_epochs=epochs,
#     243     show_progress=show_progress,
#     244     log_every_n_batches=log_every_n_batches,
#     245     heartbeat_secs=heartbeat_secs,
#     246 )
#     248 logger.info(f"Training complete ({train_time:.1f}s) | running validation...")  # noqa: G004
#     250 val_start_time = time.time()
#
# File ~\Desktop\Université\Research\qml-quansistor-entropy\qqe\src\GNN\training\train.py:131, in _run_train_epoch(model, loader, optimizer, loss_fn, scaler, device, use_amp, grad_clip, epoch_idx, num_epochs, show_progress, log_every_n_batches, heartbeat_secs)
#     128     scaler.unscale_(optimizer)
#     129     torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=float(grad_clip))
# --> 131 scaler.step(optimizer)
#     132 scaler.update()
#     134 total_loss += float(loss.item()) * batch_size
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\amp\grad_scaler.py:478, in GradScaler.step(self, optimizer, *args, **kwargs)
#     475 if len(optimizer_state["found_inf_per_device"]) == 0:
#     476     raise AssertionError("No inf checks were recorded for this optimizer.")
# --> 478 retval = self._maybe_opt_step(optimizer, optimizer_state, *args, **kwargs)
#     480 optimizer_state["stage"] = OptState.STEPPED
#     482 return retval
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\amp\grad_scaler.py:371, in GradScaler._maybe_opt_step(self, optimizer, optimizer_state, *args, **kwargs)
#     363 def _maybe_opt_step(
#     364     self,
#     365     optimizer: torch.optim.Optimizer,
#    (...)    368     **kwargs: Any,
#     369 ) -> float | None:
#     370     retval: float | None = None
# --> 371     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     372         retval = optimizer.step(*args, **kwargs)
#     373     return retval
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\amp\grad_scaler.py:371, in <genexpr>(.0)
#     363 def _maybe_opt_step(
#     364     self,
#     365     optimizer: torch.optim.Optimizer,
#    (...)    368     **kwargs: Any,
#     369 ) -> float | None:
#     370     retval: float | None = None
# --> 371     if not sum(v.item() for v in optimizer_state["found_inf_per_device"].values()):
#     372         retval = optimizer.step(*args, **kwargs)
#     373     return retval
#
# KeyboardInterrupt:

# %%
seed = np.random.randint(0, 10000)
model_type="nn"
epochs = 30
lr = 1e-4
loss_type = "huber"   # "mse" | "huber"
batch_size = 32
training_mode = "per_family"  # "global" | "per_family"
family = "random"  # required if training_mode == "per_family"
target = "sre"
data_dir = "../outputs/data/datasets"
model_save_path = "../outputs/models/random_model_nn.pt"
show_progress=True
show_val_progress=False
log_every_n_batches=10
heartbeat_secs=60.0
epoch_time_warning_secs=600.0
study_name = f"optuna_search_{model_type}_{training_mode}_{family}_{target}_{seed}"
storage_url = "sqlite:///optuna_studies.db"
n_trials = 10

optuna_search(
    model_type=model_type,
    training_mode=training_mode,
    family=family,
    data_dir=data_dir,
    target=target,
    study_name=study_name,
    storage_url=storage_url,
    n_trials=n_trials,
)
# Out:
# 2026-05-28 12:50:41,243 - scripts.optuna_search - INFO - Starting Optuna hyperparameter search...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 21
#      17 study_name = f"optuna_search_{model_type}_{training_mode}_{family}_{target}_{seed}"
#      18 storage_url = "sqlite:///optuna_studies.db"
#      19 n_trials = 10
#      20
# ---> 21 optuna_search(
#      22     model_type=model_type,
#      23     training_mode=training_mode,
#      24     family=family,
#
# File ~\Desktop\Université\Research\qml-quansistor-entropy\qqe\scripts\optuna_search.py:38, in main(model_type, training_mode, family, data_dir, target, epochs, n_trials, study_name, storage_url)
#      36 seed = np.random.randint(0, 10000)
#      37 logger.info(f"Starting Optuna hyperparameter search...")
# ---> 38 data_paths = collect_dataset_paths(
#      39     data_dir,
#      40     family=family if training_mode == "per_family" else None,
#      41     split="target",
#      42 )
#      44 logger.info(f"Found {len(data_paths)} dataset files for target={target} in data_dir={data_dir}.")
#      46 prepared_data = prepare_datasets(
#      47     data_paths,
#      48     loader_kind=model_type,
#    (...)     54     family_projection=family if training_mode == "per_family" else None,
#      55 )
#
# File ~\Desktop\Université\Research\qml-quansistor-entropy\qqe\src\GNN\training\utils.py:225, in collect_dataset_paths(dataset_root, family, split)
#     222 filtered: list[Path] = []
#     224 for path in paths:
# --> 225     payload = torch.load(path, map_location="cpu", weights_only=False)
#     226     has_target = bool(payload.get("meta", {}).get("has_target", "sre" in payload or "ee" in payload))
#     228     if split == "target" and has_target or (split == "prediction" and not has_target):
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\serialization.py:1530, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1527 if "encoding" not in pickle_load_args:
#    1528     pickle_load_args["encoding"] = "utf-8"
# -> 1530 with _open_file_like(f, "rb") as opened_file:
#    1531     if _is_zipfile(opened_file):
#    1532         # The zipfile reader is going to advance the current file position.
#    1533         # If we want to actually tail call to torch.jit.load, we need to
#    1534         # reset back to the original position.
#    1535         orig_position = opened_file.tell()
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\serialization.py:795, in _open_file_like(name_or_buffer, mode)
#     793 def _open_file_like(name_or_buffer: FileLike, mode: str) -> _opener[IO[bytes]]:
#     794     if _is_path(name_or_buffer):
# --> 795         return _open_file(name_or_buffer, mode)
#     796     else:
#     797         if "w" in mode:
#
# File c:\Users\Victor\Desktop\Université\Research\qml-quansistor-entropy\qqe\.venv\Lib\site-packages\torch\serialization.py:776, in _open_file.__init__(self, name, mode)
#     775 def __init__(self, name: str | os.PathLike[str], mode: str) -> None:
# --> 776     super().__init__(open(name, mode))
#
# KeyboardInterrupt:
